# %%
import pandas as pd
import numpy
import numpy as np
import statistics as st
from scipy.stats import mode, skew, kurtosis
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error, root_mean_squared_error, mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset
from datetime import datetime, timedelta
from pmdarima import auto_arima
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, LSTM, RNN, GRU, Dropout, Activation

# %%
bnb_df = pd.read_csv("./BNB Historical Data.csv")
bnb_df
# Out:
#             Date   Price    Open    High     Low     Vol. Change %
# 0     06/01/2024  601.80  593.80  608.19  593.20  161.02K    1.35%
# 1     05/31/2024  593.80  594.99  598.89  590.10  175.98K   -0.20%
# 2     05/30/2024  594.99  595.69  601.80  586.60  233.89K   -0.10%
# 3     05/29/2024  595.59  601.69  603.59  593.29  219.96K   -1.01%
# 4     05/28/2024  601.69  603.80  605.48  594.29  294.76K   -0.35%
# ...          ...     ...     ...     ...     ...      ...      ...
# 1915  03/05/2019   13.65   11.40   13.74   11.40    8.34M   19.61%
# 1916  03/04/2019   11.41   11.45   11.51   10.88    2.74M   -0.29%
# 1917  03/03/2019   11.45   11.75   11.86   11.20    2.86M   -2.58%
# 1918  03/02/2019   11.75   11.35   11.80   10.83    3.89M    3.56%
# 1919  03/01/2019   11.35   10.27   11.55   10.24    4.02M   10.45%
#
# [1920 rows x 7 columns]

# %% [markdown]
# ### Pre-processing Data

# %%
print(bnb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1920 entries, 0 to 1919
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1920 non-null   object
#  1   Price     1920 non-null   float64
#  2   Open      1920 non-null   float64
#  3   High      1920 non-null   float64
#  4   Low       1920 non-null   float64
#  5   Vol.      1920 non-null   object
#  6   Change %  1920 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 105.1+ KB
# None

# %% [markdown]
# * Định dạng lại cột `Date` để nó trở thành dạng `datetime`
# * Xử lý và chuyển đổi kiểu dữ liệu của cột `Vol.` và `Change %` thành kiểu float

# %%
bnb_df['Date'] = pd.to_datetime(bnb_df['Date'])
bnb_df['Vol.'] = bnb_df['Vol.'].str.replace('M', 'e6').str.replace('K', 'e3').fillna('0')
bnb_df['Vol.'] = bnb_df['Vol.'].astype(float)
bnb_df['Change %'] = bnb_df['Change %'].str.replace('%', '').astype(float)
bnb_df.reset_index(drop=True)
bnb_df.set_index('Date', inplace=True)
bnb_df.sort_index(ascending=True, inplace=True)
bnb_df
# Out:
#              Price    Open    High     Low       Vol.  Change %
# Date
# 2019-03-01   11.35   10.27   11.55   10.24  4020000.0     10.45
# 2019-03-02   11.75   11.35   11.80   10.83  3890000.0      3.56
# 2019-03-03   11.45   11.75   11.86   11.20  2860000.0     -2.58
# 2019-03-04   11.41   11.45   11.51   10.88  2740000.0     -0.29
# 2019-03-05   13.65   11.40   13.74   11.40  8340000.0     19.61
# ...            ...     ...     ...     ...        ...       ...
# 2024-05-28  601.69  603.80  605.48  594.29   294760.0     -0.35
# 2024-05-29  595.59  601.69  603.59  593.29   219960.0     -1.01
# 2024-05-30  594.99  595.69  601.80  586.60   233890.0     -0.10
# 2024-05-31  593.80  594.99  598.89  590.10   175980.0     -0.20
# 2024-06-01  601.80  593.80  608.19  593.20   161020.0      1.35
#
# [1920 rows x 6 columns]

# %%
missing_values = bnb_df.isnull().sum()
print("Missing values:\n", missing_values)
# Out:
# Missing values:
#  Price       0
# Open        0
# High        0
# Low         0
# Vol.        0
# Change %    0
# dtype: int64

# %%
print(bnb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1920 entries, 2019-03-01 to 2024-06-01
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Price     1920 non-null   float64
#  1   Open      1920 non-null   float64
#  2   High      1920 non-null   float64
#  3   Low       1920 non-null   float64
#  4   Vol.      1920 non-null   float64
#  5   Change %  1920 non-null   float64
# dtypes: float64(6)
# memory usage: 105.0 KB
# None

# %%
bnb_description = bnb_df.describe()
bnb_description
# Out:
#              Price         Open         High          Low          Vol.  \
# count  1920.000000  1920.000000  1920.000000  1920.000000  1.920000e+03
# mean    229.552547   229.245161   235.806146   222.272714  4.316261e+06
# std     184.430107   184.300217   189.692063   178.382323  2.135747e+07
# min       9.250000     9.250000    10.410000     6.500000  8.993000e+04
# 25%      27.030000    27.027500    27.807500    26.082500  5.633800e+05
# 50%     247.550000   247.055000   254.285000   242.050000  1.600000e+06
# 75%     332.110000   331.345000   339.792500   322.325000  3.772500e+06
# max     676.560000   676.250000   690.870000   634.810000  3.995400e+08
#
#           Change %
# count  1920.000000
# mean      0.329344
# std       4.891566
# min     -44.080000
# 25%      -1.610000
# 50%       0.130000
# 75%       2.160000
# max      69.990000

# %%
# Descriptive statistics for Price
print('More Price Statistics:')

print('Mode:', bnb_df['Price'].mode().values[0])
print('Standard Deviation:', bnb_df['Price'].std())
print('Variance:', bnb_df['Price'].var())
print('Kurtosis:', bnb_df['Price'].kurt())
print('Skewness:', bnb_df['Price'].skew())
# Out:
# More Price Statistics:
# Mode: 23.01
# Standard Deviation: 184.43010721388004
# Variance: 34014.46444692328
# Kurtosis: -0.8960616714167435
# Skewness: 0.33018718587724455

# %% [markdown]
# ##### Price by Date Plot

# %%
plt.figure(figsize=(12, 6))
plt.plot(bnb_df['Price'], label='Price', color='b')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Historical BNB Price from 1/3/2019 to 1/3/2024')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ##### Boxplot for Price

# %%
plt.figure(figsize=(12, 6))
plt.boxplot(bnb_df['Price'])
plt.grid()
plt.show()

# %% [markdown]
# ### Parameter

# %%
window_size = 10
feature_dim = 5
test_size=0.2

# model params
lstm_neurons = 20
rnn_neurons = 20
epochs = 100
batch_size = 4
loss = 'mae'
dropout = 0.25
optimizer = 'adam'

# %% [markdown]
# ### Split data

# %%
train_ratio = 0.8
test_ratio = 0.2

# %%
train_data = int(len(bnb_df)*train_ratio)
test_data = train_data + int(len(bnb_df)*test_ratio)

print('train index: ',train_data)
print('test index: ',test_data)
# Out:
# train index:  1536
# test index:  1920

# %%
train_df = bnb_df.iloc[:train_data]
test_df  = bnb_df[train_data:test_data]

print('train_df.shape: ',train_df.shape)
print('test_df.shape: ',test_df.shape)
# Out:
# train_df.shape:  (1536, 6)
# test_df.shape:  (384, 6)

# %%
plt.figure(figsize=(12,6))
plt.plot(pd.DataFrame(train_df).index.to_list(), pd.DataFrame(train_df['Price']), color='r', label='Train')
plt.plot(pd.DataFrame(test_df).index.to_list(),pd.DataFrame(test_df['Price']),color='b' ,label ='Test')
plt.legend()
plt.show()

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
train_df_scaled = scaler.fit_transform(train_df)
test_df_scaled = scaler.transform(test_df)

train_df_scaled = pd.DataFrame(train_df_scaled, index=train_df.index, columns=train_df.columns)
test_df_scaled = pd.DataFrame(test_df_scaled, index=test_df.index, columns=test_df.columns)

# %%
print('train_df_scaled shape: ',train_df_scaled.shape)
print('test_df_scaled shape: ',test_df_scaled.shape)
# Out:
# train_df_scaled shape:  (1536, 6)
# test_df_scaled shape:  (384, 6)

# %%
# Define the target variable
target = 'Price'

# %%
# Split data into features and target
X_train = train_df_scaled.drop(columns=target).values
y_train = train_df_scaled[target]

X_test = test_df_scaled.drop(columns=target).values
y_test = test_df_scaled[target]

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### Linear Regression

# %%
# Train Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions
y_pred_test_lr = model.predict(X_test)

# %% [markdown]
# ##### Evaluate Linear Regression

# %%
# Evaluate model on test set
mape_test_lr = mean_absolute_percentage_error(y_test, y_pred_test_lr)
mae_test_lr = mean_absolute_error(y_test, y_pred_test_lr)
rmse_test_lr = root_mean_squared_error(y_test, y_pred_test_lr)

print("Test Set MAPE: ", mape_test_lr)
print("Test Set MAE: ", mae_test_lr)
print("Test Set RMSE: ", rmse_test_lr)
# Out:
# Test Set MAPE:  0.006293440409255999
# Test Set MAE:  0.0033543878535910363
# Test Set RMSE:  0.00606010965726143

# %%
plt.figure(figsize=(12, 6))
plt.plot(pd.DataFrame(y_train).index.to_list(),pd.DataFrame(y_train),color='red',label='Train value')
plt.plot(pd.DataFrame(y_test).index.to_list(), pd.DataFrame(y_test), color='blue', label='Test value')
plt.plot(pd.DataFrame(y_test).index.to_list(), pd.DataFrame(y_pred_test_lr.reshape(-1)), color='g', label='Predicted test value')
plt.legend()
plt.show()

# %% [markdown]
# #### ARIMA

# %%
y_train
# Out:
# Date
# 2019-03-01    0.003147
# 2019-03-02    0.003746
# 2019-03-03    0.003297
# 2019-03-04    0.003237
# 2019-03-05    0.006594
#                 ...
# 2023-05-10    0.457134
# 2023-05-11    0.446944
# 2023-05-12    0.448592
# 2023-05-13    0.451754
# 2023-05-14    0.453822
# Name: Price, Length: 1536, dtype: float64

# %%
stepwise_model = auto_arima(y_train, start_p=1, start_q=1,
                            max_p=5, max_q=5, m=1,
                            start_P=0, seasonal=False,
                            d=None, D=0, trace=True,
                            error_action='ignore',  
                            suppress_warnings=True, 
                            stepwise=True)

print(stepwise_model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-7513.270, Time=0.50 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-7480.169, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-7510.954, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-7506.246, Time=0.25 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-7481.872, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-7512.004, Time=1.10 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-7520.054, Time=1.29 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-7519.912, Time=0.09 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-7524.642, Time=1.18 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-7513.054, Time=0.87 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-7516.348, Time=1.31 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-7516.416, Time=0.38 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-7516.982, Time=0.20 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=-7531.126, Time=1.73 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=-7539.363, Time=1.21 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=-7526.959, Time=1.55 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : AIC=-7536.823, Time=0.98 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : AIC=-7534.701, Time=1.88 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=-7539.312, Time=1.57 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=-7531.812, Time=1.53 sec
#  ARIMA(5,1,4)(0,0,0)[0] intercept   : AIC=-7532.180, Time=2.23 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=-7540.920, Time=0.36 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=-7532.915, Time=0.80 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=-7533.968, Time=0.68 sec
#  ARIMA(5,1,3)(0,0,0)[0]             : AIC=-7538.491, Time=0.33 sec
#  ARIMA(4,1,4)(0,0,0)[0]             : AIC=-7536.425, Time=0.90 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=-7514.833, Time=0.46 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=-7541.027, Time=1.04 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=-7531.799, Time=0.66 sec
#  ARIMA(3,1,5)(0,0,0)[0]             : AIC=-7537.052, Time=1.08 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=-7518.045, Time=0.78 sec
#  ARIMA(2,1,5)(0,0,0)[0]             : AIC=-7539.498, Time=0.88 sec
#  ARIMA(4,1,5)(0,0,0)[0]             : AIC=-7537.356, Time=1.19 sec
#
# Best model:  ARIMA(3,1,4)(0,0,0)[0]
# Total fit time: 29.207 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1536
# Model:               SARIMAX(3, 1, 4)   Log Likelihood                3778.514
# Date:                Fri, 14 Jun 2024   AIC                          -7541.027
# Time:                        13:37:11   BIC                          -7498.337
# Sample:                    03-01-2019   HQIC                         -7525.142
#                          - 05-14-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.2900      0.073    -17.650      0.000      -1.433      -1.147
# ar.L2         -0.9710      0.105     -9.253      0.000      -1.177      -0.765
# ar.L3         -0.3874      0.077     -5.065      0.000      -0.537      -0.238
# ma.L1          1.1525      0.075     15.323      0.000       1.005       1.300
# ma.L2          0.8954      0.098      9.174      0.000       0.704       1.087
# ma.L3          0.4270      0.065      6.574      0.000       0.300       0.554
# ma.L4          0.1154      0.018      6.372      0.000       0.080       0.151
# sigma2         0.0004   5.01e-06     84.982      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):             41427.59
# Prob(Q):                              0.78   Prob(JB):                         0.00
# Heteroskedasticity (H):             139.07   Skew:                            -0.56
# Prob(H) (two-sided):                  0.00   Kurtosis:                        28.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
y_pred_test_arima = stepwise_model.predict(n_periods=len(X_test))
mape_test_arima = mean_absolute_percentage_error(y_test, y_pred_test_arima)
mae_test_arima = mean_absolute_error(y_test, y_pred_test_arima)
rmse_test_arima = root_mean_squared_error(y_test, y_pred_test_arima)

print("Test Set MAPE: ", mape_test_arima)
print("Test Set MAE: ", mae_test_arima)
print("Test Set RMSE: ", rmse_test_arima)
# Out:
# Test Set MAPE:  0.3142018482723595
# Test Set MAE:  0.16194884246522756
# Test Set RMSE:  0.21247146779829146

# %%
plt.figure(figsize=(12, 6))
plt.plot(pd.DataFrame(y_train).index.to_list(),pd.DataFrame(y_train),color='red',label='Train value')
plt.plot(pd.DataFrame(y_test).index.to_list(), pd.DataFrame(y_test), color='blue', label='Test value')
plt.plot(pd.DataFrame(y_test).index.to_list(), pd.DataFrame(y_pred_test_arima), color='g', label='Predicted test value')
plt.legend()
plt.show()

# %% [markdown]
# #### GRU

# %%
X_train_GRU = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
y_train_GRU = y_train.values


X_test_GRU = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
y_test_GRU = y_test

# %%
# Xây dựng mô hình GRU
model_GRU = Sequential()
model_GRU.add(GRU(50, return_sequences=True, input_shape=(1, X_train_GRU.shape[2])))
model_GRU.add(GRU(50, return_sequences=False))
model_GRU.add(Dense(25))
model_GRU.add(Dense(1))

# Compile mô hình
model_GRU.compile(optimizer='adam', loss='mean_squared_error')

# Huấn luyện mô hình
history_GRU = model_GRU.fit(X_train_GRU, y_train_GRU, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# c:\Users\VU HOANG\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.1091
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0151
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4536e-04
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7061e-04
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0553e-04
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5807e-04
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1847e-04
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9188e-04
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8176e-04
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0345e-04
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4831e-04
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7982e-04
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4397e-04
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1975e-04
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3755e-04
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1044e-04
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0392e-04
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1042e-04
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6007e-05
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.5124e-05
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.7402e-05
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.8939e-05
# Epoch 24/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0268e-04
# Epoch 25/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.4941e-05
# Epoch 26/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.1234e-05
# Epoch 27/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.6147e-05
# Epoch 28/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.1197e-05
# Epoch 29/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.7358e-05
# Epoch 30/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6345e-05
# Epoch 31/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6006e-05
# Epoch 32/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.9894e-05
# Epoch 33/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.4080e-05
# Epoch 34/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.2020e-05
# Epoch 35/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.7595e-05
# Epoch 36/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.7207e-05
# Epoch 37/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6827e-05
# Epoch 38/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.7336e-05
# Epoch 39/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6952e-05
# Epoch 40/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6716e-05
# Epoch 41/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.4919e-05
# Epoch 42/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.8054e-05
# Epoch 43/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.6323e-05
# Epoch 44/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.9522e-05
# Epoch 45/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.4297e-05
# Epoch 46/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.9928e-05
# Epoch 47/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.3602e-05
# Epoch 48/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.8568e-05
# Epoch 49/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6916e-05
# Epoch 50/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.2661e-05
# Epoch 51/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.3258e-05
# Epoch 52/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.3577e-05
# Epoch 53/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.6467e-05
# Epoch 54/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4093e-05
# Epoch 55/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.7293e-05
# Epoch 56/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.8244e-05
# Epoch 57/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4941e-05
# Epoch 58/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.5245e-05
# Epoch 59/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6888e-05
# Epoch 60/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.4061e-05
# Epoch 61/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.5853e-05
# Epoch 62/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.3394e-05
# Epoch 63/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0980e-05
# Epoch 64/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4211e-05
# Epoch 65/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.2888e-05
# Epoch 66/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9233e-05
# Epoch 67/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5079e-05
# Epoch 68/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.1667e-05
# Epoch 69/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4598e-05
# Epoch 70/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5567e-05
# Epoch 71/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7201e-05
# Epoch 72/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5905e-05
# Epoch 73/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8445e-05
# Epoch 74/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3043e-05
# Epoch 75/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.5545e-05
# Epoch 76/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7234e-05
# Epoch 77/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0848e-05
# Epoch 78/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4576e-05
# Epoch 79/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3746e-05
# Epoch 80/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.6761e-05
# Epoch 81/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2381e-05
# Epoch 82/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0655e-05
# Epoch 83/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7080e-05
# Epoch 84/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3197e-05
# Epoch 85/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2798e-05
# Epoch 86/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3024e-05
# Epoch 87/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0882e-05
# Epoch 88/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1943e-05
# Epoch 89/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4217e-05
# Epoch 90/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6074e-05
# Epoch 91/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3237e-05
# Epoch 92/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3074e-05
# Epoch 93/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1454e-05
# Epoch 94/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3022e-05
# Epoch 95/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4986e-05
# Epoch 96/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9185e-05
# Epoch 97/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1823e-05
# Epoch 98/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0349e-05
# Epoch 99/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4659e-05
# Epoch 100/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3565e-05

# %%
# Compile mô hình
model_GRU.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Dự đoán giá
test_predict_GRU = model_GRU.predict(X_test_GRU)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step

# %%
mape_test_GRU = mean_absolute_percentage_error(y_test_GRU, test_predict_GRU)
mae_test_GRU = mean_absolute_error(y_test_GRU, test_predict_GRU)
rmse_test_GRU = root_mean_squared_error(y_test_GRU, test_predict_GRU)

print("Test Set MAPE: ", mape_test_GRU)
print("Test Set MAE: ", mae_test_GRU)
print("Test Set RMSE: ", rmse_test_GRU)
# Out:
# Test Set MAPE:  0.00564290159681137
# Test Set MAE:  0.002775052457154047
# Test Set RMSE:  0.004491234516950395

# %%
plt.figure(figsize=(12, 6))
plt.plot(pd.DataFrame(y_train).index.to_list(),pd.DataFrame(y_train),color='red',label='Train value')
plt.plot(pd.DataFrame(y_test).index.to_list(), pd.DataFrame(y_test), color='blue', label='Test value')
plt.plot(pd.DataFrame(y_test).index.to_list(), pd.DataFrame(test_predict_GRU), color='g', label='Predicted test value')
plt.legend()
plt.show()

# %% [markdown]
# #### AutoFormer
